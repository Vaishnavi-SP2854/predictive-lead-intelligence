# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df = pd.read_csv("../data/raw/bank_marketing.csv")

df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df = pd.read_csv("../data/raw/bank_marketing.csv", sep=";")

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 1 columns):
#  #   Column                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                      --------------  -----
#  0   age,job,marital,education,default,balance,housing,loan,contact,day,month,duration,campaign,pdays,previous,poutcome,deposit  11162 non-null  object
# dtypes: object(1)
# memory usage: 87.3+ KB
#        age,job,marital,education,default,balance,housing,loan,contact,day,month,duration,campaign,pdays,previous,poutcome,deposit
# count                                               11162
# unique                                              11162
# top     59,admin.,married,secondary,no,2343,yes,no,unk...
# freq                                                    1

# %%
df.isnull().sum()
# Out:
# age,job,marital,education,default,balance,housing,loan,contact,day,month,duration,campaign,pdays,previous,poutcome,deposit    0
# dtype: int64

# %%
df = pd.read_csv("../data/raw/bank_marketing.csv")
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
print(df.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
df = pd.read_csv("../data/raw/bank_marketing.csv", sep=",", engine="python")
print(df.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
df = pd.read_csv("../data/raw/bank_marketing.csv", sep=";")
print(df.columns)
# Out:
# Index(['age,job,marital,education,default,balance,housing,loan,contact,day,month,duration,campaign,pdays,previous,poutcome,deposit'], dtype='object')

# %%
df.head()
# Out:
#   age,job,marital,education,default,balance,housing,loan,contact,day,month,duration,campaign,pdays,previous,poutcome,deposit
# 0  59,admin.,married,secondary,no,2343,yes,no,unk...
# 1  56,admin.,married,secondary,no,45,no,no,unknow...
# 2  41,technician,married,secondary,no,1270,yes,no...
# 3  55,services,married,secondary,no,2476,yes,no,u...
# 4  54,admin.,married,tertiary,no,184,no,no,unknow...

# %%
df = pd.read_csv("../data/raw/bank_marketing.csv", sep=",", engine="python")
print(df.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
df['deposit'].value_counts()
# Out:
# deposit
# no     5873
# yes    5289
# Name: count, dtype: int64

# %%
df['deposit'].value_counts(normalize=True) * 100
# Out:
# deposit
# no     52.616019
# yes    47.383981
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='deposit', data=df)
plt.title("Lead Conversion Distribution")
plt.show()

# %%
df['deposit'].value_counts(normalize=True) * 100
# Out:
# deposit
# no     52.616019
# yes    47.383981
# Name: proportion, dtype: float64

# %%
pd.crosstab(df['contact'], df['deposit'], normalize='index') * 100
# Out:
# deposit           no        yes
# contact
# cellular   45.672718  54.327282
# telephone  49.612403  50.387597
# unknown    77.408355  22.591645

# %%
df.groupby('campaign')['deposit'].value_counts(normalize=True).unstack()
# Out:
# deposit         no       yes
# campaign
# 1         0.466236  0.533764
# 2         0.537318  0.462682
# 3         0.532173  0.467827
# 4         0.588846  0.411154
# 5         0.632275  0.367725
# 6         0.652830  0.347170
# 7         0.661871  0.338129
# 8         0.750000  0.250000
# 9         0.708333  0.291667
# 10        0.730769  0.269231
# 11        0.600000  0.400000
# 12        0.862069  0.137931
# 13        0.800000  0.200000
# 14        0.733333  0.266667
# 15        0.692308  0.307692
# 16        0.777778  0.222222
# 17        0.571429  0.428571
# 18        1.000000       NaN
# 19        1.000000       NaN
# 20        0.800000  0.200000
# 21        0.875000  0.125000
# 22        1.000000       NaN
# 23        1.000000       NaN
# 24        0.800000  0.200000
# 25        1.000000       NaN
# 26        1.000000       NaN
# 27        1.000000       NaN
# 28        1.000000       NaN
# 29        0.500000  0.500000
# 30        1.000000       NaN
# ...

# %%
df.groupby('loan')['deposit'].value_counts(normalize=True).unstack() * 100
# Out:
# deposit         no        yes
# loan
# no       50.474129  49.525871
# yes      66.849315  33.150685

# %% [markdown]
# # 📌 Period 1 – Data Understanding & Exploratory Data Analysis (EDA)
#
# ## 🎯 Objective
#
# The objective of this phase was to:
#
# - Load and inspect the dataset
# - Identify the target variable
# - Understand conversion distribution
# - Detect class imbalance
# - Analyze marketing channel performance
# - Extract initial business insights
#
# ---
#
# ## 📂 Dataset Overview
#
# - Dataset: **Bank Marketing Dataset**
# - Target Variable: `deposit`
#     - `yes` → Customer Converted
#     - `no` → Not Converted
#
# Each row represents a contacted lead during a marketing campaign.
#
# ---
#
# ## 📊 Target Distribution Analysis
#
# We analyzed the conversion rate using:
#
# ```python
# df['deposit'].value_counts()
# df['deposit'].value_counts(normalize=True) * 100
